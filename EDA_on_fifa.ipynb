# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fifa data.csv')
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            2036
# lcb           2036
# cb            2036
# rcb           2036
# rb            2036
# Length: 104, dtype: int64

# %%
#print colum only
column = []
for col in df.columns:
    column.append(col)
print(column)
# Out:
# ['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur', 'player_positions', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'powe
# ...

# %%
df['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Indonesia                 1
# Chinese Taipei            1
# Barbados                  1
# São Tomé & Príncipe       1
# Bahrain                   1
# Name: nationality, Length: 162, dtype: int64

# %%
df['nationality'].value_counts()[:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
print(list(df['nationality'].value_counts()[:10].keys()))
# Out:
# ['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy', 'Colombia', 'Japan', 'Netherlands']

# %%
#visalization on nationality
plt.figure(figsize=(8,8))
plt.bar(list(df['nationality'].value_counts()[:5].keys()),list(df['nationality'].value_counts()[:5]))
plt.show()

# %%
df2 = df[['short_name','wage_eur']]

# %%
df2.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
df2 =df2.sort_values(by='wage_eur',ascending=False)
df2.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 22       A. Griezmann    370000
# 5        K. De Bruyne    370000

# %%
plt.figure(figsize=(8,8))
plt.bar(list(df2['short_name'])[:5],list(df2['wage_eur'])[:5],color='y')
plt.show()

# %%
df_ger = df[df['nationality']=='Germany']
df_ger
# Out:
#        sofifa_id                                         player_url  \
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# 31        167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37        188350  https://sofifa.com/player/188350/marco-reus/20...
# 49        178603  https://sofifa.com/player/178603/mats-hummels/...
# ...          ...                                                ...
# 18123     252076  https://sofifa.com/player/252076/lukas-schelle...
# 18156     251856  https://sofifa.com/player/251856/dominik-meise...
# 18186     243537  https://sofifa.com/player/243537/maximilian-br...
# 18191     244043  https://sofifa.com/player/244043/nico-stephan/...
# 18197     244172  https://sofifa.com/player/244172/matthis-harsm...
#
#             short_name              long_name  age         dob  height_cm  \
# 6        M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# ...

# %%
df_ger.sort_values(by='weight_kg',ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 1217        M. Esser    Michael Esser   31  1987-11-22        198         97
# 77           N. Süle      Niklas Süle   23  1995-09-03        195         97
#
#       nationality                club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
df_ger[['short_name','wage_eur']].sort_values(by='wage_eur',ascending=False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %%
#shooting
df_shooting = df[['short_name','shooting']]

# %%
df_shooting.sort_values(by='shooting',ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
#defending
df_defending = df[['short_name','defending','nationality','club']]

# %%
df_defending.sort_values(by='defending',ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
df_real_madrid = df[df['club']=='Real Madrid']
df_real_madrid.head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 28     192119  https://sofifa.com/player/192119/thibaut-court...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 28   T. Courtois     Thibaut Courtois   27  1992-05-11        199         96
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# ...

# %%
df1_read_madrd = df_real_madrid[['short_name','wage_eur','nationality','defending','shooting']]
df1_read_madrd.head()
# Out:
#       short_name  wage_eur nationality  defending  shooting
# 4      E. Hazard    470000     Belgium       35.0      83.0
# 8      L. Modrić    340000     Croatia       72.0      76.0
# 18  Sergio Ramos    300000       Spain       87.0      68.0
# 28   T. Courtois    235000     Belgium        NaN       NaN
# 36      T. Kroos    330000     Germany       70.0      80.0

# %%
df1_read_madrd.sort_values(by='wage_eur',ascending=False).head()
# Out:
#       short_name  wage_eur nationality  defending  shooting
# 4      E. Hazard    470000     Belgium       35.0      83.0
# 8      L. Modrić    340000     Croatia       72.0      76.0
# 36      T. Kroos    330000     Germany       70.0      80.0
# 18  Sergio Ramos    300000       Spain       87.0      68.0
# 46    K. Benzema    285000      France       39.0      82.0

# %%
df1_read_madrd.sort_values(by='nationality',ascending=False).head()
# Out:
#            short_name  wage_eur nationality  defending  shooting
# 100           G. Bale    250000       Wales       58.0      87.0
# 1009      F. Valverde     86000     Uruguay       66.0      69.0
# 277   Nacho Fernández    165000       Spain       81.0      37.0
# 9922     De la Fuente     18000       Spain       64.0      39.0
# 8898          Fidalgo     27000       Spain       49.0      50.0

# %%
df1_read_madrd.sort_values(by='shooting',ascending=False).head()
# Out:
#        short_name  wage_eur nationality  defending  shooting
# 100       G. Bale    250000       Wales       58.0      87.0
# 106  J. Rodríguez    225000    Colombia       50.0      86.0
# 4       E. Hazard    470000     Belgium       35.0      83.0
# 46     K. Benzema    285000      France       39.0      82.0
# 161      L. Jović    155000      Serbia       29.0      82.0

# %%
df1_read_madrd.sort_values(by='defending',ascending=False).head()
# Out:
#        short_name  wage_eur nationality  defending  shooting
# 18   Sergio Ramos    300000       Spain       87.0      68.0
# 42       Casemiro    240000      Brazil       85.0      72.0
# 76      R. Varane    205000      France       85.0      45.0
# 94       Carvajal    205000       Spain       82.0      47.0
# 332  Éder Militão    105000      Brazil       81.0      50.0

# %%
df1_read_madrd['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Uruguay                1
# Colombia               1
# Japan                  1
# Serbia                 1
# Germany                1
# Costa Rica             1
# Dominican Republic     1
# Croatia                1
# Wales                  1
# Name: nationality, dtype: int64
